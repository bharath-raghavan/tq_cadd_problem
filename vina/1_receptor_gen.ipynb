# %% [markdown]
# # 1. Receptor Generation
#
# Autodock Vina requires the receptor files to be generated. This is done with the `Meeko` program, the companion llibrary to Autodock Vina. The center and box size of the receptor will have to be passed. This is fixed as a box surrounding the co-ligand. The hydrogens are added to the protein at the right pH with `PDB2PQR`.

# %%
## define binary
mk_prepapre_receptor = 'mk_prepare_receptor.py'
pdb2pqr = 'pdb2pqr'

# %% [markdown]
# Download the PDB file:

# %%
# !wget https://files.rcsb.org/view/1PPB.pdb
# Out:
# --2025-10-25 15:04:36--  https://files.rcsb.org/view/1PPB.pdb
# Resolving files.rcsb.org (files.rcsb.org)... 18.64.247.95, 18.64.247.109, 18.64.247.122, ...
# Connecting to files.rcsb.org (files.rcsb.org)|18.64.247.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 281637 (275K) [text/plain]
# Saving to: ‘1PPB.pdb’
#
# 1PPB.pdb            100%[===================>] 275.04K   353KB/s    in 0.8s
#
# 2025-10-25 15:04:37 (353 KB/s) - ‘1PPB.pdb’ saved [281637/281637]

# %% [markdown]
# Now, the protein is cleaned (all non-protein residues are removed) and written to file `1ppb_prt.pdb`. The coordinates of the co-ligand are also read.

# %%
import numpy as np
from Bio.PDB import PDBParser, PDBIO, is_aa

parser = PDBParser()
structure = parser.get_structure("1ppb", "1PPB.pdb")

coords = []
    
for model in structure:
    for chain in model:
        residues_to_delete = []
        for residue in chain:
            resname = residue.get_resname()
            if resname == '0G6':
                for atom in residue:
                    atom_name = atom.get_name()
                    atom_coordinates = atom.get_vector() # Returns a Vector object
                    coords.append(atom_coordinates.get_array())
            
            if not is_aa(residue, standard=True):  # Non-standard amino acids, ligands, water, etc.
                residues_to_delete.append(residue)
        for residue in residues_to_delete:
            chain.detach_child(residue.id)

# Save the filtered structure
io = PDBIO()
io.set_structure(structure)
io.save("1ppb_prt.pdb")

coords = np.array(coords)
# Out:
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain L is discontinuous at line 3027.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain H is discontinuous at line 3074.
#   warnings.warn(

# %% [markdown]
# Hydrogens are now added to `1ppb_prt.pdb` at physiological pH.

# %%
# !{pdb2pqr} 1ppb_prt.pdb 1ppb_clean.pqr --pH 7.4
# Out:
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# INFO:PDB2PQR v3.6.2: biomolecular structure conversion software.
# INFO:Please cite:  Jurrus E, et al.  Improvements to the APBS biomolecular solvation software suite.  Protein Sci 27 112-128 (2018).
# INFO:Please cite:  Dolinsky TJ, et al.  PDB2PQR: expanding and upgrading automated preparation of biomolecular structures for molecular simulations. Nucleic Acids Res 35 W522-W525 (2007).
# INFO:Checking and transforming input arguments.
# INFO:Loading topology files.
# INFO:Loading molecule: 1ppb_prt.pdb
# INFO:Setting up molecule.
# INFO:Created biomolecule object with 295 residues and 2380 atoms.
# INFO:Setting termini states for biomolecule chains.
# INFO:Loading forcefield.
# INFO:Loading hydrogen topology definitions.
# INFO:This biomolecule is clean.  No repair needed.
# INFO:Updating disulfide bridges.
# INFO:Debumping biomolecule.
# INFO:Adding hydrogens to biomolecule.
# INFO:Debumping biomolecule (again).
# INFO:Optimizing hydrogen bonds
# INFO:Applying force field to biomolecule states.
# INFO:Regenerating headers.
# INFO:Regenerating PDB lines.
# WARNING:Ignoring 390 header lines in output.

# %% [markdown]
# As the name suggestes, the program `pdb2pqr` outputs the protein in the `.pqr` format. This is mostly compatible with the PDB format, and most PDB readers should be able to read the PQR format as well. But, `mk_prepapre_receptor.py` breaks with this format. So, let us just load it in BioPython and right it back to a file.

# %%
parser = PDBParser()
structure = parser.get_structure("1ppb", "1ppb_clean.pqr")

# Save the filtered structure
io = PDBIO()
io.set_structure(structure)
io.save("1ppb_clean.pdb")
# Out:
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:236: PDBConstructionWarning: Negative occupancy in one or more atoms
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 1.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'N' for Atom (name=N) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 2.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'C' for Atom (name=CA) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 3.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'C' for Atom (name=C) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'O' for Atom (name=O) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 5.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'C' for Atom (name=CB) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 6.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'C' for Atom (name=CG1) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 7.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'C' for Atom (name=CG2) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 8.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'C' for Atom (name=CD1) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 9.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=H) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 10.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HA) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 11.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HB) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 12.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HG12) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 13.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HG13) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 14.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HG21) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 15.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HG22) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 16.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HG23) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 17.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HD11) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 18.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HD12) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 19.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HD13) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 20.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=H2) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 21.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=H3) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 22.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 23.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 24.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 25.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 26.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 27.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 28.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 29.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 30.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 31.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 32.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HG11) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 33.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 34.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 35.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 36.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 37.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 38.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 39.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 40.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 41.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 42.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 43.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'C' for Atom (name=CG) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 44.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'C' for Atom (name=CD) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 45.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'O' for Atom (name=OE1) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 46.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'O' for Atom (name=OE2) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 47.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 48.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 49.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HB2) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 50.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HB3) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 51.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HG2) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 52.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HG3) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 53.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 54.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 55.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 56.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 57.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 58.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HA2) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 59.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HA3) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 60.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 61.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 62.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 63.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 64.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 65.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'O' for Atom (name=OG) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 66.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 67.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 68.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 69.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 70.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HG) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 71.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 72.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 73.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 74.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 75.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 76.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 77.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'O' for Atom (name=OD1) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 78.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'O' for Atom (name=OD2) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 79.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 80.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 81.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 82.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 83.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 84.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 85.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 86.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 87.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 88.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 89.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 90.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HB1) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 91.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 92.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 93.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 94.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 95.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 96.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 97.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 98.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 99.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 100.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 101.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 102.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 103.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 104.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 105.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 106.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 107.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 108.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 109.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 110.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 111.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 112.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 113.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 114.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 115.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 116.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 117.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 118.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 119.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 120.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 121.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 122.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 123.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 124.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 125.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 126.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 127.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 128.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 129.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 130.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 131.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 132.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 133.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 134.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 135.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 136.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 137.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 138.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 139.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 140.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'S' for Atom (name=SD) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 141.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'C' for Atom (name=CE) with given element ''
#   warnings.warn(msg, PDBConstructionWarning)
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 142.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 143.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 144.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 145.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 146.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 147.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 148.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/Atom.py:232: PDBConstructionWarning: Used element 'H' for Atom (name=HE1) with given element ''
# ...
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4669.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4670.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4671.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4672.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4673.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4674.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4675.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4676.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4677.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4678.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4679.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4680.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4681.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4682.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4683.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4684.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4685.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4686.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4687.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4688.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4689.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4690.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4691.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4692.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4693.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4694.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4695.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4696.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4697.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4698.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4699.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4700.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4701.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4702.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4703.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4704.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4705.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4706.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4707.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4708.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4709.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4710.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4711.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4712.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4713.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4714.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4715.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4716.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4717.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4718.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4719.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4720.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4721.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4722.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4723.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4724.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4725.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Invalid or missing B factor at line 4726.
# Exception ignored.
# Some atoms or residues may be missing in the data structure.
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'TER' at line 4727
#   warnings.warn(
# /Users/vbf/Library/Python/3.9/lib/python/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 4728
#   warnings.warn(

# %% [markdown]
# The center of the ligand and a bounding box around the ligand (with a 6 Å) padding is also calculated.

# %%
center_coords = coords.mean(axis=0)
center = " ".join([f"{i:.2f}" for i in center_coords])
center
# Out:
# '5.04 17.14 18.38'

# %%
box_coords = (np.max(coords, axis=0)-np.min(coords, axis=0)+6).round()
box = " ".join([f"{int(i)}" for i in box_coords])
box
# Out:
# '14 11 18'

# %% [markdown]
# The center and the box coordinates are used to generate the receptor, centered on the co-ligand.

# %%
cmd = f"{mk_prepapre_receptor} -i 1ppb_clean.pdb -o 1ppb_receptor -p -v --box_size {box} --box_center {center}"
print(cmd)
# !{cmd}
# Out:
# /Users/vbf/Library/Python/3.9/bin/mk_prepare_receptor.py -i 1ppb_clean.pdb -o 1ppb_receptor -p -v --box_size 14 11 18 --box_center 5.04 17.14 18.38
# @> 4725 atoms and 1 coordinate set(s) were parsed in 0.02s.
#
# Files written:
#   1ppb_receptor.pdbqt <-- static (i.e., rigid) receptor input file
# 1ppb_receptor.box.txt <-- Vina-style box dimension file
# 1ppb_receptor.box.pdb <-- PDB file to visualize the grid box
